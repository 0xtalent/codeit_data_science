# %%
# %matplotlib inline

import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\hayong\Downloads\sports.csv', index_col=0)

# %%
df.plot()

# %%
df.plot(kind='bar')

# %%
df.plot(kind='barh')

# %%
df.plot(kind='bar', stacked=True)

# %%
df['Female']
# Out:
# Swimming      178
# Baseball      289
# Basketball     97
# Golf          232
# Soccer        109
# Bowling       129
# Name: Female, dtype: int64

# %%
df['Female'].plot(kind='bar')
