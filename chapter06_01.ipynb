# %%
# Seaborn(Statistical Data Visualization): 통계를 기반으로 한 데이터 시각화
# PDF(Probability Density Function): 확률 밀도 함수
# 확률 밀도 함수는 데이터셋의 분포를 나타낸다.
# 특정 구간의 확률은 그래프 아래 그 구간의 면적과 동일하다.
# 그래프 아래의 모든 면적을 더하면 1이 된다.

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv(r'C:\Users\hayong\Downloads\body.csv', index_col=0)
df
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0
# ...        ...     ...
# 996      171.8    68.2
# 997      171.5    75.6
# 998      177.9    66.5
# 999      174.4    72.0
# 1000     173.5    77.4
#
# [1000 rows x 2 columns]

# %%
df.head()
# Out:
#         Height  Weight
# Number
# 1        176.0    85.2
# 2        175.3    67.7
# 3        168.6    75.2
# 4        168.1    67.1
# 5        175.3    63.0

# %%
df['Height']
# Out:
# Number
# 1       176.0
# 2       175.3
# 3       168.6
# 4       168.1
# 5       175.3
#         ...
# 996     171.8
# 997     171.5
# 998     177.9
# 999     174.4
# 1000    173.5
# Name: Height, Length: 1000, dtype: float64

# %%
df['Height'].value_counts()
# Out:
# 172.5    13
# 174.9    13
# 173.2    12
# 175.2    12
# 175.3    12
#          ..
# 163.7     1
# 185.7     1
# 184.5     1
# 176.5     1
# 184.6     1
# Name: Height, Length: 262, dtype: int64

# %%
df['Height'].value_counts().sort_index()
# Out:
# 154.4    1
# 155.5    1
# 157.4    1
# 157.8    1
# 158.0    1
#         ..
# 190.3    1
# 191.2    1
# 191.8    1
# 192.4    1
# 193.1    1
# Name: Height, Length: 262, dtype: int64

# %%
df['Height'].value_counts().sort_index().plot()

# %%
sns.kdeplot(df['Height'])

# %%
sns.kdeplot(df['Height'], bw=0.05)
